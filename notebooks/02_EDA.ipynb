# %% [markdown]
# # Phase 2: Exploratory Data Analysis (EDA)
#
# This notebook explores the dataset structure, missingness, distributions, and initial hypotheses.
#
# **Goals**:
# - Understand feature types and ranges
# - Inspect missing values
# - Review target balance
# - Identify potential feature engineering ideas

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
df = pd.read_csv("../datasets/preprocessed_traffic_accident_prediction.csv")
target = pd.read_csv("../datasets/target_traffic_accident_prediction.csv")

# %%
# High Level Data Overview
print("Dataset Shape:", df.shape)
print("\nDataset Info:")
print(df.info())
print("\nDataset Description:")
print(df.describe())
# Out:
# Dataset Shape: (658, 12)
#
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 658 entries, 0 to 657
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Weather               658 non-null    str
#  1   Road_Type             658 non-null    str
#  2   Time_of_Day           658 non-null    str
#  3   Traffic_Density       658 non-null    float64
#  4   Speed_Limit           658 non-null    float64
#  5   Number_of_Vehicles    658 non-null    float64
#  6   Driver_Alcohol        658 non-null    float64
#  7   Road_Condition        658 non-null    str
#  8   Vehicle_Type          658 non-null    str
#  9   Driver_Age            658 non-null    float64
#  10  Driver_Experience     658 non-null    float64
#  11  Road_Light_Condition  658 non-null    str
# dtypes: float64(6), str(6)
# memory usage: 61.8 KB
# None
#
# Dataset Description:
#        Traffic_Density  Speed_Limit  Number_of_Vehicles  Driver_Alcohol  \
# count       658.000000   658.000000          658.000000           658.0
# mean          1.019757    67.142857            3.065350             0.0
# std           0.773164    22.139332            1.359442             0.0
# min           0.000000    30.000000            1.000000             0.0
# 25%           0.000000    50.000000            2.000000             0.0
# 50%           1.000000    60.000000            3.000000             0.0
# 75%           2.000000    80.000000            4.000000             0.0
# max           2.000000   120.000000            5.000000             0.0
#
#        Driver_Age  Driver_Experience
# count  658.000000         658.000000
# mean    43.199088          39.031915
# std     14.788459          14.975390
# min     18.000000           9.000000
# 25%     30.250000          26.000000
# 50%     43.000000          40.000000
# 75%     55.000000          52.000000
# max     69.000000          69.000000

# %%
# Countplot of target variable
plt.figure(figsize=(6, 4))
sns.countplot(x=target.values.ravel())
plt.title("Distribution of Target Variable")
plt.xlabel("Accident Occurrence")
plt.ylabel("Count")
plt.show()

# %%
# Numerical features correlation heatmap
# Select only numerical features for correlation analysis
num_cols = df.select_dtypes(include=[np.number]).columns
plt.figure(figsize=(12, 8))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %%
# Categorical Feature Analysis
cat_cols = df.select_dtypes(include=["str"]).columns
for col in cat_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(x=df[col])
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()
