# %% [markdown]
# # Phase 2: Exploratory Data Analysis (EDA)

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
df = pd.read_csv("../datasets/preprocessed_traffic_accident_prediction.csv")
target = pd.read_csv("../datasets/target_traffic_accident_prediction.csv")

# %%
# High Level Data Overview
print("Dataset Shape:", df.shape)
print("\nDataset Info:")
print(df.info())
print("\nDataset Description:")
print(df.describe())
# Out:
# Dataset Shape: (462, 12)
#
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Weather               462 non-null    str
#  1   Road_Type             462 non-null    str
#  2   Time_of_Day           462 non-null    str
#  3   Traffic_Density       462 non-null    float64
#  4   Speed_Limit           462 non-null    float64
#  5   Number_of_Vehicles    462 non-null    float64
#  6   Driver_Alcohol        462 non-null    float64
#  7   Road_Condition        462 non-null    str
#  8   Vehicle_Type          462 non-null    str
#  9   Driver_Age            462 non-null    float64
#  10  Driver_Experience     462 non-null    float64
#  11  Road_Light_Condition  462 non-null    str
# dtypes: float64(6), str(6)
# memory usage: 43.4 KB
# None
#
# Dataset Description:
#        Traffic_Density  Speed_Limit  Number_of_Vehicles  Driver_Alcohol  \
# count       462.000000   462.000000          462.000000           462.0
# mean          1.015152    66.212121            3.025974             0.0
# std           0.794359    22.436762            1.392331             0.0
# min           0.000000    30.000000            1.000000             0.0
# 25%           0.000000    50.000000            2.000000             0.0
# 50%           1.000000    60.000000            3.000000             0.0
# 75%           2.000000    80.000000            4.000000             0.0
# max           2.000000   120.000000            5.000000             0.0
#
#        Driver_Age  Driver_Experience
# count  462.000000         462.000000
# mean    43.164502          38.541126
# std     15.117580          15.365448
# min     18.000000           9.000000
# 25%     30.000000          25.000000
# 50%     43.000000          39.000000
# 75%     56.000000          52.000000
# max     69.000000          69.000000

# %%
# Countplot of target variable
plt.figure(figsize=(6, 4))
sns.countplot(x=target.values.ravel())
plt.title("Distribution of Target Variable")
plt.xlabel("Accident Occurrence")
plt.ylabel("Count")
plt.show()

# %%
# Numerical features correlation heatmap
# Select only numerical features for correlation analysis
num_cols = df.select_dtypes(include=[np.number]).columns
plt.figure(figsize=(12, 8))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %%
# Categorical Feature Analysis
cat_cols = df.select_dtypes(include=["str"]).columns
for col in cat_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(x=df[col])
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()
