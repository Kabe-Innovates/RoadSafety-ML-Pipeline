# %% [markdown]
# # Phase 4: Feature Engineering and Encoding
#
# This notebook handles feature transformation: scaling numeric features and encoding categorical features.
#
# **Goals**:
# - Scale numeric features (StandardScaler)
# - Encode categorical features (one-hot encoding)
# - Create final feature matrix for modeling
# - Explore feature interactions (optional)

# %% [markdown]
# ## Summary
# - Numeric features: StandardScaler applied (fit on train, transform on test)
# - Categorical features: One-hot encoded (fit on train, transform on test)
# - Final shape: 6 scaled numeric + many one-hot encoded categorical features
# - Ready for model training
