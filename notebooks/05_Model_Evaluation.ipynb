# %% [markdown]
# # Phase 5: Model Evaluation and Comparison
#
# Refer : [Collab Notbook](https://drive.google.com/file/d/1ezKFK13L8I6hN22BLfL9pOhH_G9ZWUYh/view?usp=sharing)

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import joblib

# %%
# Load saved models
logistic_model = joblib.load("../models/logistic_regression_model.pkl")
tree_model = joblib.load("../models/decision_tree_model.pkl")

# Load test datasets
X_test = pd.read_csv("../datasets/X_test.csv")
y_test = pd.read_csv("../datasets/y_test.csv")

# %%
# Predict and evaluate Logistic Regression Model
logistic_predictions = logistic_model.predict(X_test)
print("Logistic Regression Classification Report:")
print(classification_report(y_test, logistic_predictions))
print("Logistic Regression Confusion Matrix:")
print(confusion_matrix(y_test, logistic_predictions))
print(f"Logistic Regression Accuracy: {accuracy_score(y_test, logistic_predictions):.4f}")
# Out:
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.41      0.46        63
#          1.0       0.12      0.17      0.14        30
#
#     accuracy                           0.33        93
#    macro avg       0.31      0.29      0.30        93
# weighted avg       0.38      0.33      0.35        93
#
# Logistic Regression Confusion Matrix:
# [[26 37]
#  [25  5]]
# Logistic Regression Accuracy: 0.3333

# %%
# Predict and evaluate Decision Tree Model
tree_predictions = tree_model.predict(X_test)
print("Decision Tree Classification Report:")
print(classification_report(y_test, tree_predictions))
print("Decision Tree Confusion Matrix:")
print(confusion_matrix(y_test, tree_predictions))
print(f"Decision Tree Accuracy: {accuracy_score(y_test, tree_predictions):.4f}")
# Out:
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.70      0.67        63
#          1.0       0.24      0.20      0.22        30
#
#     accuracy                           0.54        93
#    macro avg       0.44      0.45      0.44        93
# weighted avg       0.52      0.54      0.53        93
#
# Decision Tree Confusion Matrix:
# [[44 19]
#  [24  6]]
# Decision Tree Accuracy: 0.5376

# %%
# Plot Logistic Regression CM
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, logistic_predictions), annot=True, fmt="d", cmap="Blues")
plt.title("Logistic Regression Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Plot Decision Tree CM
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, tree_predictions), annot=True, fmt="d", cmap="Greens")
plt.title("Decision Tree Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
