# %% [markdown]
# # Phase 5: Model Training
#
# Train foundational ML models on the preprocessed and encoded data.
#
# **Models**:
# - Logistic Regression
# - Decision Tree
# - Random Forest
# - Support Vector Machine (SVM)

# %% [markdown]
# ## Summary
# - All 4 foundational models trained on preprocessed data
# - Metrics saved to results/model_metrics.csv
# - Models saved to models/ directory
# - Next: Evaluate and compare models in detail
